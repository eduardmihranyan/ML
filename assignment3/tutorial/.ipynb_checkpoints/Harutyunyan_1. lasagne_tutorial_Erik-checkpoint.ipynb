# %% [markdown]
# # lasagne
# * lasagne is a library for neural network building and training
# * it's a low-level library with almost seamless integration with theano
#
# For a demo we shall solve the same digit recognition problem, but at a different scale
# * images are now 28x28
# * 10 different digits
# * 50k samples

# %%
import numpy as np
import theano
import theano.tensor as T
import matplotlib.pyplot as plt
import sys
import os

# %matplotlib inline

# %%
if sys.version_info[0] == 2:
    from urllib import urlretrieve
else:
    from urllib.request import urlretrieve

def download(filename, source='http://yann.lecun.com/exdb/mnist/'):
    print("Downloading %s" % filename)
    urlretrieve(source + filename, filename)

# We then define functions for loading MNIST images and labels.
# For convenience, they also download the requested files if needed.
import gzip

def load_mnist_images(filename):
    if not os.path.exists(filename):
        download(filename)
    # Read the inputs in Yann LeCun's binary format.
    with gzip.open(filename, 'rb') as f:
        data = np.frombuffer(f.read(), np.uint8, offset=16)
    # The inputs are vectors now, we reshape them to monochrome 2D images,
    # following the shape convention: (examples, channels, rows, columns)
    data = data.reshape(-1, 1, 28, 28)
    # The inputs come as bytes, we convert them to float32 in range [0,1].
    # (Actually to range [0, 255/256], for compatibility to the version
    # provided at http://deeplearning.net/data/mnist/mnist.pkl.gz.)
    return data / np.float32(256)

def load_mnist_labels(filename):
    if not os.path.exists(filename):
        download(filename)
    # Read the labels in Yann LeCun's binary format.
    with gzip.open(filename, 'rb') as f:
        data = np.frombuffer(f.read(), np.uint8, offset=8)
    # The labels are vectors of integers now, that's exactly what we want.
    return data

# We can now download and read the training and test set images and labels.
X_train = load_mnist_images('train-images-idx3-ubyte.gz')
y_train = load_mnist_labels('train-labels-idx1-ubyte.gz')
X_test = load_mnist_images('t10k-images-idx3-ubyte.gz')
y_test = load_mnist_labels('t10k-labels-idx1-ubyte.gz')

# We reserve the last 10000 training examples for validation.
X_train, X_val = X_train[:-10000], X_train[-10000:]
y_train, y_val = y_train[:-10000], y_train[-10000:]


print(X_train.shape,y_train.shape)
# Out:
# (50000, 1, 28, 28) (50000,)

# %%
input_X = T.tensor4("X")

#input dimention (None means "Arbitrary" and only works at  the first axes [samples])
input_shape = [None,1,28,28]

target_y = T.vector("target Y integer",dtype='int32')

# %% [markdown]
# Defining network architecture

# %%
import lasagne
from lasagne.layers import *

l_inp = InputLayer(shape = input_shape,input_var=input_X)
l1 = Conv2DLayer(l_inp, 16, (5,5))
l2 = Pool2DLayer(l1, (2,2))
l3 = Conv2DLayer(l2, 32, (3,3))
l4 = Conv2DLayer(l3, 32, (3,3))
l5 = DenseLayer(l4,num_units=100,nonlinearity = lasagne.nonlinearities.elu)
l6 = DropoutLayer(l5,p=.5)
l7 = DenseLayer(l6,num_units=150,nonlinearity = lasagne.nonlinearities.tanh)
l8 = DropoutLayer(l7,p=.5)
l_out = DenseLayer(l8,num_units = 10,nonlinearity=lasagne.nonlinearities.softmax)

# %%
#network prediction (theano-transformation)
y_predicted = lasagne.layers.get_output(l_out)

# %%
#all network weights (shared variables)
all_weights = lasagne.layers.get_all_params(l_out)
print(all_weights)
# Out:
# [W, b, W, b, W, b, W, b, W, b, W, b]

# %% [markdown]
# ### Than you could simply
# * define loss function manually
# * compute error gradient over all weights
# * define updates
# * But that's a whole lot of work and life's short
#   * not to mention life's too short to wait for SGD to converge
#
# Instead, we shall use Lasagne builtins

# %%
#Mean categorical crossentropy as a loss function - similar to logistic loss but for multiclass targets
loss = lasagne.objectives.categorical_crossentropy(y_predicted,target_y).mean()

#prediction accuracy
accuracy = lasagne.objectives.categorical_accuracy(y_predicted,target_y).mean()

#This function computes gradient AND composes weight updates just like you did earlier
updates_sgd = lasagne.updates.momentum(loss, all_weights,learning_rate=0.01,momentum=0.9)

# %%
#function that computes loss and updates weights
train_fun = theano.function([input_X,target_y],[loss,accuracy],updates= updates_sgd)

#function that just computes accuracy
accuracy_fun = theano.function([input_X,target_y],accuracy)

# %% [markdown]
# ### That's all, now let's train it!
# * We got a lot of data, so it's recommended that you use SGD
# * So let's implement a function that splits the training sample into minibatches

# %%
# An auxilary function that returns mini-batches for neural network training

#Parameters
# inputs - a tensor of images with shape (many, 1, 28, 28), e.g. X_train
# outputs - a vector of answers for corresponding images e.g. Y_train
#batch_size - a single number - the intended size of each batches

def iterate_minibatches(inputs, targets, batchsize):
    assert len(inputs) == len(targets)
    indices = np.arange(len(inputs))
    np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        excerpt = indices[start_idx:start_idx + batchsize]
        yield inputs[excerpt], targets[excerpt]

# %% [markdown]
# # Training loop

# %%
import time

num_epochs = 1000 #amount of passes through the data

batch_size = 500 #number of samples processed at each function call

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    train_err = 0
    train_acc = 0
    train_batches = 0
    start_time = time.time()
    for batch in iterate_minibatches(X_train, y_train,batch_size):
        inputs, targets = batch
        train_err_batch, train_acc_batch= train_fun(inputs, targets)
        train_err += train_err_batch
        train_acc += train_acc_batch
        train_batches += 1

    # And a full pass over the validation data:
    val_acc = 0
    val_batches = 0
    for batch in iterate_minibatches(X_val, y_val, batch_size):
        inputs, targets = batch
        val_acc += accuracy_fun(inputs, targets)
        val_batches += 1

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))

    print("  training loss (in-iteration):\t\t{:.6f}".format(train_err / train_batches))
    print("  train accuracy:\t\t{:.2f} %".format(
        train_acc / train_batches * 100))
    print("  validation accuracy:\t\t{:.2f} %".format(
        val_acc / val_batches * 100))
# Out:
# Epoch 1 of 1000 took 56.073s
#   training loss (in-iteration):		1.175829
#   train accuracy:		60.90 %
#   validation accuracy:		86.68 %
# Epoch 2 of 1000 took 56.549s
#   training loss (in-iteration):		0.330097
#   train accuracy:		89.97 %
#   validation accuracy:		93.16 %
# Epoch 3 of 1000 took 59.482s
#   training loss (in-iteration):		0.209299
#   train accuracy:		93.75 %
#   validation accuracy:		95.06 %
# Epoch 4 of 1000 took 61.319s
#   training loss (in-iteration):		0.163782
#   train accuracy:		95.12 %
#   validation accuracy:		96.51 %
# Epoch 5 of 1000 took 53.885s
#   training loss (in-iteration):		0.137390
#   train accuracy:		95.93 %
#   validation accuracy:		96.68 %
# Epoch 6 of 1000 took 57.361s
#   training loss (in-iteration):		0.120215
#   train accuracy:		96.44 %
#   validation accuracy:		97.17 %
# Epoch 7 of 1000 took 55.489s
#   training loss (in-iteration):		0.106614
#   train accuracy:		96.88 %
#   validation accuracy:		97.06 %
# Epoch 8 of 1000 took 59.009s
#   training loss (in-iteration):		0.096161
#   train accuracy:		97.13 %
#   validation accuracy:		97.41 %
# Epoch 9 of 1000 took 56.790s
#   training loss (in-iteration):		0.088396
#   train accuracy:		97.38 %
#   validation accuracy:		97.78 %
# Epoch 10 of 1000 took 57.729s
#   training loss (in-iteration):		0.081274
#   train accuracy:		97.54 %
#   validation accuracy:		97.50 %
# Epoch 11 of 1000 took 53.150s
#   training loss (in-iteration):		0.076208
#   train accuracy:		97.75 %
#   validation accuracy:		97.85 %
# Epoch 12 of 1000 took 68.756s
#   training loss (in-iteration):		0.072820
#   train accuracy:		97.85 %
#   validation accuracy:		97.90 %
# Epoch 13 of 1000 took 64.685s
#   training loss (in-iteration):		0.067413
#   train accuracy:		98.03 %
#   validation accuracy:		97.98 %
# Epoch 14 of 1000 took 66.320s
#   training loss (in-iteration):		0.062931
#   train accuracy:		98.15 %
#   validation accuracy:		97.93 %
# Epoch 15 of 1000 took 51.311s
#   training loss (in-iteration):		0.062142
#   train accuracy:		98.10 %
#   validation accuracy:		98.30 %
# Epoch 16 of 1000 took 50.879s
#   training loss (in-iteration):		0.058548
#   train accuracy:		98.31 %
#   validation accuracy:		97.96 %
# Epoch 17 of 1000 took 51.159s
#   training loss (in-iteration):		0.054631
#   train accuracy:		98.33 %
#   validation accuracy:		98.18 %
# Epoch 18 of 1000 took 51.713s
#   training loss (in-iteration):		0.052463
#   train accuracy:		98.40 %
#   validation accuracy:		98.19 %
# Epoch 19 of 1000 took 51.469s
#   training loss (in-iteration):		0.051259
#   train accuracy:		98.49 %
#   validation accuracy:		98.34 %
# Epoch 20 of 1000 took 51.550s
#   training loss (in-iteration):		0.048610
#   train accuracy:		98.58 %
#   validation accuracy:		98.40 %
# Epoch 21 of 1000 took 51.597s
#   training loss (in-iteration):		0.046100
#   train accuracy:		98.58 %
#   validation accuracy:		98.40 %
# Epoch 22 of 1000 took 51.562s
#   training loss (in-iteration):		0.044386
#   train accuracy:		98.69 %
#   validation accuracy:		98.42 %
# Epoch 23 of 1000 took 51.608s
#   training loss (in-iteration):		0.043078
#   train accuracy:		98.72 %
#   validation accuracy:		98.44 %
# Epoch 24 of 1000 took 51.781s
#   training loss (in-iteration):		0.043327
#   train accuracy:		98.70 %
#   validation accuracy:		98.44 %
# Epoch 25 of 1000 took 53.181s
#   training loss (in-iteration):		0.042214
#   train accuracy:		98.71 %
#   validation accuracy:		98.50 %
# Epoch 26 of 1000 took 52.575s
#   training loss (in-iteration):		0.040428
#   train accuracy:		98.82 %
#   validation accuracy:		98.41 %
# Epoch 27 of 1000 took 52.465s
#   training loss (in-iteration):		0.037215
#   train accuracy:		98.86 %
#   validation accuracy:		98.52 %
# Epoch 28 of 1000 took 52.263s
#   training loss (in-iteration):		0.037107
#   train accuracy:		98.91 %
#   validation accuracy:		98.49 %
# Epoch 29 of 1000 took 52.276s
#   training loss (in-iteration):		0.036510
#   train accuracy:		98.89 %
#   validation accuracy:		98.72 %
# Epoch 30 of 1000 took 52.544s
#   training loss (in-iteration):		0.034706
#   train accuracy:		98.88 %
#   validation accuracy:		98.47 %
# Epoch 31 of 1000 took 52.226s
#   training loss (in-iteration):		0.034814
#   train accuracy:		98.96 %
#   validation accuracy:		98.78 %
# Epoch 32 of 1000 took 52.216s
#   training loss (in-iteration):		0.032282
#   train accuracy:		98.98 %
#   validation accuracy:		98.61 %
# Epoch 33 of 1000 took 52.236s
#   training loss (in-iteration):		0.031405
#   train accuracy:		99.04 %
#   validation accuracy:		98.67 %
# Epoch 34 of 1000 took 52.282s
#   training loss (in-iteration):		0.032107
#   train accuracy:		99.03 %
#   validation accuracy:		98.56 %
# Epoch 35 of 1000 took 52.527s
#   training loss (in-iteration):		0.029414
#   train accuracy:		99.12 %
#   validation accuracy:		98.68 %
# Epoch 36 of 1000 took 61.489s
#   training loss (in-iteration):		0.029681
#   train accuracy:		99.07 %
#   validation accuracy:		98.70 %
# Epoch 37 of 1000 took 65.253s
#   training loss (in-iteration):		0.027969
#   train accuracy:		99.16 %
#   validation accuracy:		98.74 %
# Epoch 38 of 1000 took 73.213s
#   training loss (in-iteration):		0.027759
#   train accuracy:		99.13 %
#   validation accuracy:		98.80 %
# Epoch 39 of 1000 took 62.595s
#   training loss (in-iteration):		0.028393
#   train accuracy:		99.13 %
#   validation accuracy:		98.73 %
# Epoch 40 of 1000 took 69.399s
#   training loss (in-iteration):		0.027304
#   train accuracy:		99.17 %
#   validation accuracy:		98.82 %
# Epoch 41 of 1000 took 72.127s
#   training loss (in-iteration):		0.025622
#   train accuracy:		99.23 %
#   validation accuracy:		98.66 %
# Epoch 42 of 1000 took 56.238s
#   training loss (in-iteration):		0.024691
#   train accuracy:		99.25 %
#   validation accuracy:		98.74 %
# Epoch 43 of 1000 took 74.588s
#   training loss (in-iteration):		0.025137
#   train accuracy:		99.21 %
#   validation accuracy:		98.69 %
# Epoch 44 of 1000 took 67.225s
#   training loss (in-iteration):		0.024533
#   train accuracy:		99.26 %
#   validation accuracy:		98.85 %
# Epoch 45 of 1000 took 74.616s
#   training loss (in-iteration):		0.024207
#   train accuracy:		99.28 %
#   validation accuracy:		98.90 %
# Epoch 46 of 1000 took 68.606s
#   training loss (in-iteration):		0.023014
#   train accuracy:		99.28 %
#   validation accuracy:		98.71 %
# Epoch 47 of 1000 took 68.384s
#   training loss (in-iteration):		0.022510
#   train accuracy:		99.29 %
#   validation accuracy:		98.85 %
# Epoch 48 of 1000 took 68.485s
#   training loss (in-iteration):		0.021057
#   train accuracy:		99.32 %
#   validation accuracy:		98.91 %
# Epoch 49 of 1000 took 68.153s
#   training loss (in-iteration):		0.022371
#   train accuracy:		99.31 %
#   validation accuracy:		98.80 %
# Epoch 50 of 1000 took 68.799s
#   training loss (in-iteration):		0.020846
#   train accuracy:		99.34 %
#   validation accuracy:		98.87 %
# Epoch 51 of 1000 took 68.503s
#   training loss (in-iteration):		0.021273
#   train accuracy:		99.32 %
#   validation accuracy:		98.62 %
# Epoch 52 of 1000 took 68.772s
#   training loss (in-iteration):		0.019872
#   train accuracy:		99.38 %
#   validation accuracy:		98.71 %
# Epoch 53 of 1000 took 72.982s
#   training loss (in-iteration):		0.018702
#   train accuracy:		99.41 %
#   validation accuracy:		98.87 %
# Epoch 54 of 1000 took 71.323s
#   training loss (in-iteration):		0.020304
#   train accuracy:		99.32 %
#   validation accuracy:		98.97 %
# Epoch 55 of 1000 took 71.422s
#   training loss (in-iteration):		0.019985
#   train accuracy:		99.38 %
#   validation accuracy:		98.86 %
# Epoch 56 of 1000 took 70.609s
#   training loss (in-iteration):		0.018068
#   train accuracy:		99.42 %
#   validation accuracy:		98.81 %
# Epoch 57 of 1000 took 66.399s
#   training loss (in-iteration):		0.017372
#   train accuracy:		99.48 %
#   validation accuracy:		98.86 %
# Epoch 58 of 1000 took 63.239s
#   training loss (in-iteration):		0.017580
#   train accuracy:		99.47 %
#   validation accuracy:		98.96 %
# Epoch 59 of 1000 took 52.535s
#   training loss (in-iteration):		0.017626
#   train accuracy:		99.46 %
#   validation accuracy:		98.99 %
# Epoch 60 of 1000 took 52.584s
#   training loss (in-iteration):		0.017692
#   train accuracy:		99.45 %
#   validation accuracy:		98.80 %
# Epoch 61 of 1000 took 52.778s
#   training loss (in-iteration):		0.016632
#   train accuracy:		99.46 %
#   validation accuracy:		98.81 %
# Epoch 62 of 1000 took 55.162s
#   training loss (in-iteration):		0.016729
#   train accuracy:		99.47 %
#   validation accuracy:		98.87 %
# Epoch 63 of 1000 took 53.173s
#   training loss (in-iteration):		0.015857
#   train accuracy:		99.51 %
#   validation accuracy:		98.81 %
# Epoch 64 of 1000 took 55.913s
#   training loss (in-iteration):		0.018578
#   train accuracy:		99.42 %
#   validation accuracy:		98.76 %
# Epoch 65 of 1000 took 59.793s
#   training loss (in-iteration):		0.015405
#   train accuracy:		99.49 %
#   validation accuracy:		98.90 %
# Epoch 66 of 1000 took 55.394s
#   training loss (in-iteration):		0.015069
#   train accuracy:		99.53 %
#   validation accuracy:		98.78 %
# Epoch 67 of 1000 took 57.236s
#   training loss (in-iteration):		0.013740
#   train accuracy:		99.55 %
#   validation accuracy:		98.82 %
# Epoch 68 of 1000 took 59.531s
#   training loss (in-iteration):		0.014369
#   train accuracy:		99.58 %
#   validation accuracy:		98.93 %
# Epoch 69 of 1000 took 56.114s
#   training loss (in-iteration):		0.013933
#   train accuracy:		99.55 %
#   validation accuracy:		98.96 %
# Epoch 70 of 1000 took 56.291s
#   training loss (in-iteration):		0.014672
#   train accuracy:		99.54 %
#   validation accuracy:		98.95 %
# Epoch 71 of 1000 took 58.180s
#   training loss (in-iteration):		0.014758
#   train accuracy:		99.51 %
#   validation accuracy:		98.90 %
# Epoch 72 of 1000 took 56.163s
#   training loss (in-iteration):		0.013464
#   train accuracy:		99.55 %
#   validation accuracy:		98.84 %
# Epoch 73 of 1000 took 56.179s
#   training loss (in-iteration):		0.013371
#   train accuracy:		99.59 %
#   validation accuracy:		98.90 %
# Epoch 74 of 1000 took 56.269s
#   training loss (in-iteration):		0.013838
#   train accuracy:		99.56 %
#   validation accuracy:		98.98 %
# Epoch 75 of 1000 took 56.095s
#   training loss (in-iteration):		0.013813
#   train accuracy:		99.56 %
#   validation accuracy:		98.83 %
# Epoch 76 of 1000 took 58.544s
#   training loss (in-iteration):		0.011718
#   train accuracy:		99.65 %
#   validation accuracy:		98.94 %
# Epoch 77 of 1000 took 58.062s
#   training loss (in-iteration):		0.011625
#   train accuracy:		99.62 %
#   validation accuracy:		98.93 %
# Epoch 78 of 1000 took 57.197s
#   training loss (in-iteration):		0.011767
#   train accuracy:		99.66 %
#   validation accuracy:		98.95 %
# Epoch 79 of 1000 took 56.082s
#   training loss (in-iteration):		0.011877
#   train accuracy:		99.62 %
#   validation accuracy:		98.82 %
# Epoch 80 of 1000 took 56.266s
#   training loss (in-iteration):		0.012014
#   train accuracy:		99.62 %
#   validation accuracy:		98.75 %
# Epoch 81 of 1000 took 56.220s
#   training loss (in-iteration):		0.012009
#   train accuracy:		99.63 %
#   validation accuracy:		99.00 %
# Epoch 82 of 1000 took 56.824s
#   training loss (in-iteration):		0.011314
#   train accuracy:		99.65 %
#   validation accuracy:		98.95 %
# Epoch 83 of 1000 took 56.252s
#   training loss (in-iteration):		0.011980
#   train accuracy:		99.62 %
#   validation accuracy:		98.99 %
# Epoch 84 of 1000 took 56.235s
#   training loss (in-iteration):		0.010587
#   train accuracy:		99.65 %
#   validation accuracy:		98.94 %
# Epoch 85 of 1000 took 56.242s
#   training loss (in-iteration):		0.010652
#   train accuracy:		99.67 %
#   validation accuracy:		98.90 %
# Epoch 86 of 1000 took 56.325s
#   training loss (in-iteration):		0.010151
#   train accuracy:		99.66 %
#   validation accuracy:		98.87 %
# Epoch 87 of 1000 took 56.191s
#   training loss (in-iteration):		0.010598
#   train accuracy:		99.66 %
#   validation accuracy:		98.95 %
# Epoch 88 of 1000 took 56.306s
#   training loss (in-iteration):		0.009861
#   train accuracy:		99.66 %
#   validation accuracy:		98.88 %
# Epoch 89 of 1000 took 56.275s
#   training loss (in-iteration):		0.010251
#   train accuracy:		99.66 %
#   validation accuracy:		98.96 %
# Epoch 90 of 1000 took 56.187s
#   training loss (in-iteration):		0.009678
#   train accuracy:		99.68 %
#   validation accuracy:		98.91 %
# Epoch 91 of 1000 took 56.507s
#   training loss (in-iteration):		0.009756
#   train accuracy:		99.67 %
#   validation accuracy:		98.94 %
# Epoch 92 of 1000 took 56.623s
#   training loss (in-iteration):		0.009535
#   train accuracy:		99.67 %
#   validation accuracy:		99.00 %
# Epoch 93 of 1000 took 56.392s
#   training loss (in-iteration):		0.010245
#   train accuracy:		99.67 %
#   validation accuracy:		98.94 %
# Epoch 94 of 1000 took 56.549s
#   training loss (in-iteration):		0.008628
#   train accuracy:		99.73 %
#   validation accuracy:		98.88 %
# Epoch 95 of 1000 took 56.689s
#   training loss (in-iteration):		0.009836
#   train accuracy:		99.66 %
#   validation accuracy:		98.92 %
# Epoch 96 of 1000 took 56.353s
#   training loss (in-iteration):		0.009699
#   train accuracy:		99.69 %
#   validation accuracy:		98.98 %
# Epoch 97 of 1000 took 56.613s
#   training loss (in-iteration):		0.008725
#   train accuracy:		99.72 %
#   validation accuracy:		98.87 %
# Epoch 98 of 1000 took 56.200s
#   training loss (in-iteration):		0.008565
#   train accuracy:		99.72 %
#   validation accuracy:		99.03 %
# Epoch 99 of 1000 took 57.392s
#   training loss (in-iteration):		0.009876
#   train accuracy:		99.68 %
#   validation accuracy:		98.96 %
# Epoch 100 of 1000 took 57.449s
#   training loss (in-iteration):		0.010007
#   train accuracy:		99.69 %
#   validation accuracy:		99.12 %
# Epoch 101 of 1000 took 56.646s
#   training loss (in-iteration):		0.008096
#   train accuracy:		99.75 %
#   validation accuracy:		98.89 %
# Epoch 102 of 1000 took 57.058s
#   training loss (in-iteration):		0.007210
#   train accuracy:		99.77 %
#   validation accuracy:		99.03 %
# Epoch 103 of 1000 took 58.244s
#   training loss (in-iteration):		0.007375
#   train accuracy:		99.78 %
#   validation accuracy:		98.80 %
# Epoch 104 of 1000 took 58.230s
#   training loss (in-iteration):		0.007409
#   train accuracy:		99.77 %
#   validation accuracy:		99.04 %
# Epoch 105 of 1000 took 58.435s
#   training loss (in-iteration):		0.007969
#   train accuracy:		99.74 %
#   validation accuracy:		98.94 %
# Epoch 106 of 1000 took 58.319s
#   training loss (in-iteration):		0.008485
#   train accuracy:		99.70 %
#   validation accuracy:		98.97 %
# Epoch 107 of 1000 took 58.184s
#   training loss (in-iteration):		0.007788
#   train accuracy:		99.74 %
#   validation accuracy:		99.01 %
# Epoch 108 of 1000 took 58.355s
#   training loss (in-iteration):		0.006683
#   train accuracy:		99.80 %
#   validation accuracy:		98.89 %
# Epoch 109 of 1000 took 58.329s
#   training loss (in-iteration):		0.006939
#   train accuracy:		99.78 %
#   validation accuracy:		98.96 %
# Epoch 110 of 1000 took 58.144s
#   training loss (in-iteration):		0.007428
#   train accuracy:		99.76 %
#   validation accuracy:		98.91 %
# Epoch 111 of 1000 took 58.219s
#   training loss (in-iteration):		0.007342
#   train accuracy:		99.77 %
#   validation accuracy:		99.03 %
# Epoch 112 of 1000 took 58.183s
#   training loss (in-iteration):		0.006598
#   train accuracy:		99.80 %
#   validation accuracy:		99.00 %
# Epoch 113 of 1000 took 58.228s
#   training loss (in-iteration):		0.007530
#   train accuracy:		99.73 %
#   validation accuracy:		98.93 %
# Epoch 114 of 1000 took 58.768s
#   training loss (in-iteration):		0.007406
#   train accuracy:		99.75 %
#   validation accuracy:		99.00 %
# Epoch 115 of 1000 took 58.240s
#   training loss (in-iteration):		0.006742
#   train accuracy:		99.75 %
#   validation accuracy:		99.00 %
# Epoch 116 of 1000 took 60.331s
#   training loss (in-iteration):		0.005726
#   train accuracy:		99.82 %
#   validation accuracy:		98.91 %
# Epoch 117 of 1000 took 55.315s
#   training loss (in-iteration):		0.007210
#   train accuracy:		99.76 %
#   validation accuracy:		98.88 %
# Epoch 118 of 1000 took 55.322s
#   training loss (in-iteration):		0.007249
#   train accuracy:		99.75 %
#   validation accuracy:		99.01 %
# Epoch 119 of 1000 took 55.215s
#   training loss (in-iteration):		0.007220
#   train accuracy:		99.75 %
#   validation accuracy:		98.96 %
# Epoch 120 of 1000 took 55.269s
#   training loss (in-iteration):		0.006254
#   train accuracy:		99.81 %
#   validation accuracy:		98.99 %
# Epoch 121 of 1000 took 55.223s
#   training loss (in-iteration):		0.005563
#   train accuracy:		99.82 %
#   validation accuracy:		98.94 %
# Epoch 122 of 1000 took 55.336s
#   training loss (in-iteration):		0.005843
#   train accuracy:		99.82 %
#   validation accuracy:		99.00 %
# Epoch 123 of 1000 took 55.253s
#   training loss (in-iteration):		0.005251
#   train accuracy:		99.84 %
#   validation accuracy:		98.92 %
# Epoch 124 of 1000 took 55.346s
#   training loss (in-iteration):		0.006010
#   train accuracy:		99.81 %
#   validation accuracy:		98.99 %
# Epoch 125 of 1000 took 55.356s
#   training loss (in-iteration):		0.005881
#   train accuracy:		99.81 %
#   validation accuracy:		98.96 %
# Epoch 126 of 1000 took 55.314s
#   training loss (in-iteration):		0.005914
#   train accuracy:		99.79 %
#   validation accuracy:		99.08 %
# Epoch 127 of 1000 took 55.302s
#   training loss (in-iteration):		0.005651
#   train accuracy:		99.82 %
#   validation accuracy:		98.82 %
# Epoch 128 of 1000 took 55.246s
#   training loss (in-iteration):		0.005532
#   train accuracy:		99.81 %
#   validation accuracy:		99.01 %
# Epoch 129 of 1000 took 55.647s
#   training loss (in-iteration):		0.005418
#   train accuracy:		99.82 %
#   validation accuracy:		99.07 %
# Epoch 130 of 1000 took 55.287s
#   training loss (in-iteration):		0.005119
#   train accuracy:		99.82 %
#   validation accuracy:		98.99 %
# Epoch 131 of 1000 took 55.345s
#   training loss (in-iteration):		0.005544
#   train accuracy:		99.83 %
#   validation accuracy:		99.02 %
# Epoch 132 of 1000 took 55.233s
#   training loss (in-iteration):		0.006272
#   train accuracy:		99.80 %
#   validation accuracy:		98.92 %
# Epoch 133 of 1000 took 55.411s
#   training loss (in-iteration):		0.005068
#   train accuracy:		99.82 %
#   validation accuracy:		98.96 %
# Epoch 134 of 1000 took 55.500s
#   training loss (in-iteration):		0.005666
#   train accuracy:		99.83 %
#   validation accuracy:		98.94 %
# Epoch 135 of 1000 took 55.447s
#   training loss (in-iteration):		0.006313
#   train accuracy:		99.78 %
#   validation accuracy:		98.99 %
# Epoch 136 of 1000 took 55.399s
#   training loss (in-iteration):		0.005767
#   train accuracy:		99.82 %
#   validation accuracy:		98.97 %
# Epoch 137 of 1000 took 55.482s
#   training loss (in-iteration):		0.004789
#   train accuracy:		99.84 %
#   validation accuracy:		99.05 %
# Epoch 138 of 1000 took 55.622s
#   training loss (in-iteration):		0.004720
#   train accuracy:		99.85 %
#   validation accuracy:		98.86 %
# Epoch 139 of 1000 took 55.672s
#   training loss (in-iteration):		0.004845
#   train accuracy:		99.84 %
#   validation accuracy:		98.96 %
# Epoch 140 of 1000 took 55.801s
#   training loss (in-iteration):		0.005100
#   train accuracy:		99.81 %
#   validation accuracy:		98.99 %
# Epoch 141 of 1000 took 55.725s
#   training loss (in-iteration):		0.004138
#   train accuracy:		99.86 %
#   validation accuracy:		99.01 %
# Epoch 142 of 1000 took 55.752s
#   training loss (in-iteration):		0.004727
#   train accuracy:		99.85 %
#   validation accuracy:		99.05 %
# Epoch 143 of 1000 took 55.788s
#   training loss (in-iteration):		0.005258
#   train accuracy:		99.83 %
#   validation accuracy:		98.97 %
# Epoch 144 of 1000 took 56.202s
#   training loss (in-iteration):		0.004340
#   train accuracy:		99.86 %
#   validation accuracy:		99.10 %
# Epoch 145 of 1000 took 56.044s
#   training loss (in-iteration):		0.004411
#   train accuracy:		99.86 %
#   validation accuracy:		98.98 %
# Epoch 146 of 1000 took 56.400s
#   training loss (in-iteration):		0.004417
#   train accuracy:		99.86 %
#   validation accuracy:		99.04 %
# Epoch 147 of 1000 took 56.594s
#   training loss (in-iteration):		0.004430
#   train accuracy:		99.86 %
#   validation accuracy:		99.07 %
# Epoch 148 of 1000 took 56.545s
#   training loss (in-iteration):		0.003603
#   train accuracy:		99.89 %
#   validation accuracy:		99.06 %
# Epoch 149 of 1000 took 58.418s
#   training loss (in-iteration):		0.004332
#   train accuracy:		99.86 %
#   validation accuracy:		99.06 %
# Epoch 150 of 1000 took 65.845s
#   training loss (in-iteration):		0.004368
#   train accuracy:		99.87 %
#   validation accuracy:		99.11 %
# Epoch 151 of 1000 took 60.381s
#   training loss (in-iteration):		0.004031
#   train accuracy:		99.87 %
#   validation accuracy:		98.96 %
# Epoch 152 of 1000 took 52.913s
#   training loss (in-iteration):		0.004317
#   train accuracy:		99.85 %
#   validation accuracy:		99.05 %
# Epoch 153 of 1000 took 58.444s
#   training loss (in-iteration):		0.004700
#   train accuracy:		99.85 %
#   validation accuracy:		99.03 %
# Epoch 154 of 1000 took 53.989s
#   training loss (in-iteration):		0.003667
#   train accuracy:		99.90 %
#   validation accuracy:		99.04 %
# Epoch 155 of 1000 took 53.900s
#   training loss (in-iteration):		0.004855
#   train accuracy:		99.86 %
#   validation accuracy:		98.99 %
# Epoch 156 of 1000 took 54.556s
#   training loss (in-iteration):		0.003973
#   train accuracy:		99.87 %
#   validation accuracy:		98.96 %
# Epoch 157 of 1000 took 54.669s
#   training loss (in-iteration):		0.003663
#   train accuracy:		99.87 %
#   validation accuracy:		99.00 %
# Epoch 158 of 1000 took 54.900s
#   training loss (in-iteration):		0.003264
#   train accuracy:		99.91 %
#   validation accuracy:		99.02 %
# Epoch 159 of 1000 took 52.369s
#   training loss (in-iteration):		0.003519
#   train accuracy:		99.88 %
#   validation accuracy:		99.07 %
# Epoch 160 of 1000 took 52.334s
#   training loss (in-iteration):		0.003743
#   train accuracy:		99.88 %
#   validation accuracy:		99.00 %
# Epoch 161 of 1000 took 52.479s
#   training loss (in-iteration):		0.003659
#   train accuracy:		99.88 %
#   validation accuracy:		99.14 %
# Epoch 162 of 1000 took 52.208s
#   training loss (in-iteration):		0.003290
#   train accuracy:		99.88 %
#   validation accuracy:		99.11 %
# Epoch 163 of 1000 took 52.536s
#   training loss (in-iteration):		0.003969
#   train accuracy:		99.87 %
#   validation accuracy:		98.95 %
# Epoch 164 of 1000 took 53.540s
#   training loss (in-iteration):		0.003761
#   train accuracy:		99.87 %
#   validation accuracy:		99.15 %
# Epoch 165 of 1000 took 53.333s
#   training loss (in-iteration):		0.004000
#   train accuracy:		99.88 %
#   validation accuracy:		99.00 %
# Epoch 166 of 1000 took 53.349s
#   training loss (in-iteration):		0.003547
#   train accuracy:		99.90 %
#   validation accuracy:		99.07 %
# Epoch 167 of 1000 took 53.517s
#   training loss (in-iteration):		0.004107
#   train accuracy:		99.84 %
#   validation accuracy:		99.02 %
# Epoch 168 of 1000 took 53.567s
#   training loss (in-iteration):		0.004132
#   train accuracy:		99.87 %
#   validation accuracy:		99.12 %
# Epoch 169 of 1000 took 53.417s
#   training loss (in-iteration):		0.003722
#   train accuracy:		99.88 %
#   validation accuracy:		99.02 %
# Epoch 170 of 1000 took 53.655s
#   training loss (in-iteration):		0.003201
#   train accuracy:		99.88 %
#   validation accuracy:		98.98 %
# Epoch 171 of 1000 took 53.331s
#   training loss (in-iteration):		0.003436
#   train accuracy:		99.89 %
#   validation accuracy:		99.08 %
# Epoch 172 of 1000 took 53.479s
#   training loss (in-iteration):		0.003891
#   train accuracy:		99.89 %
#   validation accuracy:		98.99 %
# Epoch 173 of 1000 took 53.457s
#   training loss (in-iteration):		0.003779
#   train accuracy:		99.88 %
#   validation accuracy:		99.01 %
# Epoch 174 of 1000 took 53.434s
#   training loss (in-iteration):		0.002970
#   train accuracy:		99.90 %
#   validation accuracy:		99.06 %
# Epoch 175 of 1000 took 53.548s
#   training loss (in-iteration):		0.003604
#   train accuracy:		99.88 %
#   validation accuracy:		98.92 %
# Epoch 176 of 1000 took 53.508s
#   training loss (in-iteration):		0.003470
#   train accuracy:		99.88 %
#   validation accuracy:		99.18 %
# Epoch 177 of 1000 took 53.562s
#   training loss (in-iteration):		0.003939
#   train accuracy:		99.88 %
#   validation accuracy:		99.13 %
# Epoch 178 of 1000 took 53.488s
#   training loss (in-iteration):		0.003420
#   train accuracy:		99.89 %
#   validation accuracy:		99.21 %
# Epoch 179 of 1000 took 53.534s
#   training loss (in-iteration):		0.002663
#   train accuracy:		99.93 %
#   validation accuracy:		99.10 %
# Epoch 180 of 1000 took 53.526s
#   training loss (in-iteration):		0.003384
#   train accuracy:		99.88 %
#   validation accuracy:		98.98 %
# Epoch 181 of 1000 took 53.517s
#   training loss (in-iteration):		0.003394
#   train accuracy:		99.88 %
#   validation accuracy:		99.01 %
# Epoch 182 of 1000 took 53.452s
#   training loss (in-iteration):		0.002922
#   train accuracy:		99.89 %
#   validation accuracy:		99.05 %
# Epoch 183 of 1000 took 53.465s
#   training loss (in-iteration):		0.003117
#   train accuracy:		99.90 %
#   validation accuracy:		99.04 %
# Epoch 184 of 1000 took 53.538s
#   training loss (in-iteration):		0.002679
#   train accuracy:		99.93 %
#   validation accuracy:		99.06 %
# Epoch 185 of 1000 took 53.487s
#   training loss (in-iteration):		0.003051
#   train accuracy:		99.89 %
#   validation accuracy:		99.03 %
# Epoch 186 of 1000 took 53.511s
#   training loss (in-iteration):		0.003063
#   train accuracy:		99.90 %
#   validation accuracy:		99.07 %
# Epoch 187 of 1000 took 55.560s
#   training loss (in-iteration):		0.002934
#   train accuracy:		99.90 %
#   validation accuracy:		99.02 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-0ef54f3eba1e> in <module>()
#      13     for batch in iterate_minibatches(X_train, y_train,batch_size):
#      14         inputs, targets = batch
# ---> 15         train_err_batch, train_acc_batch= train_fun(inputs, targets)
#      16         train_err += train_err_batch
#      17         train_acc += train_acc_batch
#
# /home/ero/anaconda3/lib/python3.6/site-packages/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# KeyboardInterrupt:

# %%
test_acc = 0
test_batches = 0
for batch in iterate_minibatches(X_test, y_test, 500):
    inputs, targets = batch
    acc = accuracy_fun(inputs, targets)
    test_acc += acc
    test_batches += 1
print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_acc / test_batches * 100))

if test_acc / test_batches * 100 > 99:
    print ("Achievement unlocked: 80lvl Warlock!")
else:
    print ("We need more magic!")
    
# Unfortunately I can't train on GPU (I have ATI RADEON graphic card), and training takes a lot of time, the convolution
# net architecture I used above is a prototype of LeNet, which after 500 iterations is said to give an accuracy around
# 99.2%
# Out:
# Final results:
#   test accuracy:		99.03 %
# Achievement unlocked: 80lvl Warlock!

# %% [markdown]
# # Now improve it!
#
# * Moar layers!
# * Moar units!
# * Different nonlinearities!
